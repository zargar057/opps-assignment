# %% [markdown]
# **Python OOPs Questions**

# %% [markdown]
# 1. What is Object-Oriented Programming (OOP)?
#
# OOP is a way of writing programs using objects. Objects are things that have data (like a name or age) and actions (like speaking or walking). OOP makes code easier to reuse, understand, and update.

# %% [markdown]
# 2. What is a class in OOP?
#
# A class is like a blueprint or template for creating objects. For example, a "Car" class can be used to make many car objects.

# %% [markdown]
# 3. What is an object in OOP?
#
# An object is a real thing created from a class. If "Car" is a class, then a red Honda is an object of that class.

# %% [markdown]
# 4. What is the difference between abstraction and encapsulation?
#
# Abstraction hides details and shows only what’s needed (like a remote control hides complex wiring).Encapsulation keeps data safe by hiding it inside the object and only allowing changes through methods.

# %% [markdown]
# 5. What are dunder methods in Python?
#
# Dunder methods are special methods with double underscores (like __init__, __str__). They let your objects work like built-in types (e.g., printing, adding).

# %% [markdown]
# 6. What is inheritance in OOP?
#
# Inheritance lets one class (child) get features from another class (parent). For example, a "Dog" class can inherit from an "Animal" class.

# %% [markdown]
# 7. What is polymorphism in OOP?
#
# Polymorphism means many forms. It lets different objects use the same method name but behave differently. For example, both a bird and a plane can "fly", but in their own way.

# %% [markdown]
# 8. How is encapsulation done in Python?
#
# We use private variables (with __) and create methods like get_balance() to hide and protect data.

# %% [markdown]
# 9. What is a constructor in Python?
#
# A constructor is the __init__() method. It runs automatically when you create an object and sets its starting values.

# %% [markdown]
# 10. What are class and static methods in Python?
#
# @classmethod works on the class itself, not the object.
#
# @staticmethod is just a normal function inside a class — it doesn’t need the class or object.

# %% [markdown]
# 11. What is method overloading in Python?
#
# Python doesn't allow real method overloading (same name, different arguments). Instead, we use default values or *args to handle many inputs.

# %% [markdown]
# 12. What is method overriding in OOP?
#
# Method overriding means a child class changes a method it got from its parent class.

# %% [markdown]
# 13. What is a property decorator in Python?
#
# @property lets you use a method like a variable. It’s useful for things that are calculated but should look like simple values.

# %% [markdown]
# 14. Why is polymorphism useful?
#
# It helps you use the same code for different types of objects. This makes your program more flexible and easier to update.

# %% [markdown]
# 15. What is an abstract class in Python?
#
# An abstract class is a class you can’t create directly. It’s like a guide for other classes — they must fill in the missing parts.

# %% [markdown]
# 16. What are the benefits of OOP?
#
# Reuse code (inheritance)
#
# Keep code organized (classes)
#
# Hide details (encapsulation)
#
# Use one name for many actions (polymorphism)
#
# Easy to update and understand

# %% [markdown]
# 17. What’s the difference between class and instance variables?
#
# Class variable is shared by all objects.
#
# Instance variable is unique to each object.

# %% [markdown]
# 18. What is multiple inheritance in Python?
#
# It means a class can get features from more than one parent class.

# %% [markdown]
# 19. What is __str__ and __repr__ in Python?
#
# __str__ is for readable output (for users).
#
# __repr__ is for debugging (for developers).

# %% [markdown]
# 20. What does super() do in Python?
#
# super() lets a child class call a method from its parent, often used to keep the parent's behavior.

# %% [markdown]
# 21. What is the __del__ method in Python?
#
# __del__ is called when an object is about to be deleted. It's used to clean up resources, like closing a file.

# %% [markdown]
# 22. What’s the difference between @staticmethod and @classmethod?
#
# @staticmethod doesn’t use the class or object.
#
# @classmethod gets the class as a parameter and can change class-level data.

# %% [markdown]
# 23. How does polymorphism work with inheritance in Python?
#
# A parent class has a method, and each child class can have its own version. Python calls the right one based on the object.

# %% [markdown]
# 24. What is method chaining in Python?
#
# It means calling multiple methods one after another in a single line, like:
#
# obj.set_name("Sam").set_age(20).show()

# %% [markdown]
# 25. What is the purpose of __call__ in Python?
#
# It lets an object act like a function. If you define __call__, you can call the object like obj().

# %% [markdown]
# **Practical Questions**

# %%
''' Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog
that overrides the speak() method to print "Bark!".'''
class Animal:
    def speak(self):
        print("Animal makes a sound")

class Dog(Animal):
    def speak(self):
        print("Bark!")

dog = Dog()
dog.speak()
# Out:
# Bark!

# %%
'''2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
from it and implement the area() method in both.'''
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, r):
        self.r = r

    def area(self):
        return 3.14 * self.r * self.r

class Rectangle(Shape):
    def __init__(self, w, h):
        self.w = w
        self.h = h

    def area(self):
        return self.w * self.h

c = Circle(5)
r = Rectangle(4, 6)

print("Circle Area:", c.area())
print("Rectangle Area:", r.area())
# Out:
# Circle Area: 78.5
# Rectangle Area: 24

# %%
'''3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
and further derive a class ElectricCar that adds a battery attribute.'''
class Vehicle:
    def __init__(self, type):
        self.type = type

class Car(Vehicle):
    def __init__(self, type, model):
        super().__init__(type)
        self.model = model

class ElectricCar(Car):
    def __init__(self, type, model, battery):
        super().__init__(type, model)
        self.battery = battery

e_car = ElectricCar("Four Wheeler", "Tesla Model 3", "75 kWh")
print(e_car.type, e_car.model, e_car.battery)
# Out:
# Four Wheeler Tesla Model 3 75 kWh

# %%
'''4. Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes
Sparrow and Penguin that override the fly() method.'''
class Bird:
    def fly(self):
        print("Bird is flying")

class Sparrow(Bird):
    def fly(self):
        print("Sparrow can fly")

class Penguin(Bird):
    def fly(self):
        print("Penguin can't fly")

b1 = Sparrow()
b2 = Penguin()

b1.fly()
b2.fly()
# Out:
# Sparrow can fly
# Penguin can't fly

# %%
'''5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
balance and methods to deposit, withdraw, and check balance.'''
class BankAccount:
    def __init__(self):
        self.__balance = 0

    def deposit(self, amount):
        self.__balance += amount

    def withdraw(self, amount):
        if amount <= self.__balance:
            self.__balance -= amount
        else:
            print("Insufficient funds")

    def get_balance(self):
        return self.__balance

acc = BankAccount()
acc.deposit(1000)
acc.withdraw(300)
print("Balance:", acc.get_balance())
# Out:
# Balance: 700

# %%
'''6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
and Piano that implement their own version of play().'''
class Instrument:
    def play(self):
        print("Playing an instrument")

class Guitar(Instrument):
    def play(self):
        print("Strumming guitar")

class Piano(Instrument):
    def play(self):
        print("Playing piano")

i1 = Guitar()
i2 = Piano()

i1.play()
i2.play()
# Out:
# Strumming guitar
# Playing piano

# %%
'''7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static
method subtract_numbers() to subtract two numbers.'''
class MathOperations:
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        return a - b

print("Add:", MathOperations.add_numbers(5, 3))
print("Subtract:", MathOperations.subtract_numbers(9, 4))
# Out:
# Add: 8
# Subtract: 5

# %%
#8. Implement a class Person with a class method to count the total number of persons created.
class Person:
    count = 0

    def __init__(self, name):
        self.name = name
        Person.count += 1

    @classmethod
    def get_count(cls):
        return cls.count

p1 = Person("Alice")
p2 = Person("Bob")
print("Total persons:", Person.get_count())
# Out:
# Total persons: 2

# %%
'''9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the
fraction as "numerator/denominator".'''
class Fraction:
    def __init__(self, num, den):
        self.num = num
        self.den = den

    def __str__(self):
        return f"{self.num}/{self.den}"

f = Fraction(3, 4)
print(f)
# Out:
# 3/4

# %%
'''10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two
vectors.'''
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):
        return f"({self.x}, {self.y})"

v1 = Vector(2, 3)
v2 = Vector(4, 1)
v3 = v1 + v2
print("Vector sum:", v3)
# Out:
# Vector sum: (6, 4)

# %%
'''11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
{name} and I am {age} years old.'''
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

p = Person("John", 25)
p.greet()
# Out:
# Hello, my name is John and I am 25 years old.

# %%
'''12. Implement a class Student with attributes name and grades. Create a method average_grade() to compute
the average of the grades.'''
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades

    def average_grade(self):
        return sum(self.grades) / len(self.grades)

s = Student("Anu", [90, 80, 70])
print("Average Grade:", s.average_grade())
# Out:
# Average Grade: 80.0

# %%
'''13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the
area.'''
class Rectangle:
    def set_dimensions(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height

r = Rectangle()
r.set_dimensions(5, 4)
print("Area:", r.area())
# Out:
# Area: 20

# %%
'''14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
and hourly rate. Create a derived class Manager that adds a bonus to the salary.'''
class Employee:
    def calculate_salary(self, hours, rate):
        return hours * rate

class Manager(Employee):
    def calculate_salary(self, hours, rate, bonus):
        return super().calculate_salary(hours, rate) + bonus

m = Manager()
print("Manager Salary:", m.calculate_salary(40, 50, 500))
# Out:
# Manager Salary: 2500

# %%
'''15. Create a class Product with attributes name, price, and quantity. Implement a method total_price() that
calculates the total price of the product.'''
class Product:
    def __init__(self, name, price, qty):
        self.name = name
        self.price = price
        self.qty = qty

    def total_price(self):
        return self.price * self.qty

p = Product("Pen", 10, 5)
print("Total Price:", p.total_price())
# Out:
# Total Price: 50

# %%
'''16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
implement the sound() method.'''
from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

class Cow(Animal):
    def sound(self):
        print("Moo")

class Sheep(Animal):
    def sound(self):
        print("Baa")

c = Cow()
s = Sheep()
c.sound()
s.sound()
# Out:
# Moo
# Baa

# %%
'''17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
returns a formatted string with the book's details.'''
class Book:
    def __init__(self, title, author, year):
        self.title = title
        self.author = author
        self.year = year

    def get_book_info(self):
        return f"{self.title} by {self.author} ({self.year})"

b = Book("1984", "George Orwell", 1949)
print(b.get_book_info())
# Out:
# 1984 by George Orwell (1949)

# %%
'''18. Create a class House with attributes address and price. Create a derived class Mansion that adds an
attribute number_of_rooms.'''
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

class Mansion(House):
    def __init__(self, address, price, rooms):
        super().__init__(address, price)
        self.rooms = rooms

m = Mansion("123 Palace Rd", 500000, 10)
print(m.address, m.price, m.rooms)
# Out:
# 123 Palace Rd 500000 10
